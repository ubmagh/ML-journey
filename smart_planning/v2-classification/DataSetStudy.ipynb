# %% [markdown]
# # Smart Planning : appreciation model - appreciation - the dataset study
#
# ### Details
#
# - Problem : `Regression`
#
#
# - Models :
#     * scikit Linear Regression Model
#
#
# - label : Classes (1: Good, 0: Bad)
#
#
# - Values in percentage to avoid the problem related to a specefic number of classrooms, teachers ...
#
#
# <br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sn
# %matplotlib inline

# %% [markdown]
# # Get the dataset

# %%
df = pd.read_excel("dataset2.xlsx")
df.head()
# Out:
#    SC_simultanite_Perc  salles_utilisees_Perc  salles_surutiliseess_Perc  \
# 0                    4                      0                          0
# 1                   13                     10                         20
# 2                   17                    100                        100
# 3                   16                     70                         30
# 4                   17                     12                         20
#
#    places_videss_Perc  seances_samedis_Perc  Smidis_Perc  IntvDep8Hs_Perc  \
# 0                   0                     2            4                6
# 1                  25                    20            2               25
# 2                  28                     0            6               26
# 3                   0                     1            2               26
# 4                   3                     0            3               26
#
#    InterDepDisp6s_Perc  GrpDep8Hs_Perc  GrpDepDisp6s_Perc  SHDispoIntrv_Nbr  \
# 0                    2               5                 20                 1
# 1                    6               2                  8                10
# 2                    6               3                 22                 0
# 3                   10               3                  0                 4
# 4                    8               2                  0                22
#
#    SDepDIntvs_Perc  SHPDIntvs_Perc  Label
# 0                1               0      1
# 1               30              10      1
# 2               20              33      0
# 3                5               3      1
# 4                1               3      1

# %% [markdown]
# # Insights about the dataset

# %%
print("# DataSet shape : ", df.shape)
df.describe()
# Out:
# # DataSet shape :  (70, 14)
#        SC_simultanite_Perc  salles_utilisees_Perc  salles_surutiliseess_Perc  \
# count            70.000000              70.000000                  70.000000
# mean             29.414286              57.142857                  36.171429
# std              31.865429              31.375836                  30.035231
# min               0.000000               0.000000                   0.000000
# 25%              10.000000              30.500000                  11.250000
# 50%              16.000000              69.000000                  29.000000
# 75%              32.750000              80.000000                  55.000000
# max             100.000000             100.000000                 100.000000
#
#        places_videss_Perc  seances_samedis_Perc  Smidis_Perc  IntvDep8Hs_Perc  \
# count           70.000000             70.000000    70.000000        70.000000
# mean            31.485714             37.342857    37.985714        34.214286
# std             28.989625             35.418363    37.313203        26.893722
# min              0.000000              0.000000     0.000000         0.000000
# 25%              9.000000              4.250000     3.000000        15.000000
# 50%             24.000000             23.000000    30.000000        26.000000
# 75%             50.750000             70.750000    76.750000        53.000000
# max             98.000000            100.000000   100.000000       100.000000
#
#        InterDepDisp6s_Perc  GrpDep8Hs_Perc  GrpDepDisp6s_Perc  \
# count            70.000000       70.000000          70.000000
# mean             36.642857       30.771429          35.257143
# std              32.420711       31.008260          29.916156
# min               0.000000        0.000000           0.000000
# 25%              10.000000        5.000000          12.000000
# 50%              25.000000       19.000000          27.500000
# 75%              59.750000       46.000000          56.000000
# max             100.000000      100.000000         100.000000
#
#        SHDispoIntrv_Nbr  SDepDIntvs_Perc  SHPDIntvs_Perc      Label
# count         70.000000        70.000000       70.000000  70.000000
# mean          17.242857        34.528571       33.328571   0.371429
# std           18.792101        31.489921       32.374494   0.486675
# min            0.000000         0.000000        0.000000   0.000000
# 25%            5.000000         8.500000        6.000000   0.000000
# 50%           14.000000        22.500000       22.000000   0.000000
# 75%           21.750000        59.750000       57.500000   1.000000
# max          100.000000       100.000000      100.000000   1.000000

# %% [markdown]
# ### Count Label values
#
# > Bad planning are more than good ones

# %%
sn.countplot(x = 'Label',data = df)
plt.show()

# %% [markdown]
# ## features histogrames

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# <br>
#
# ### scatter plot matrix : ploting each pair of features

# %%
# Scatter plot matrix : better to open the image in a new tab
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (80, 80));

# %% [markdown]
# <br>
#
# ### SeaBorn pairplot : ploting each pair of features

# %%
# Pairplot : better to open the image in a new tab
sn.set(rc = {'figure.figsize':(80,80)}) 
sn.pairplot(data = df) # same as the one before, here we can present 3 variables in the same graph, for example 'Label'
plt.show()            # Variable but using color (intensity?) hue; added the argument hue="Label" to pairplot()

# %% [markdown]
# <br>
#
# ### Correlation HeatMap (Matrix)

# %%
corr_mat = df.corr()
sn.set(rc = {'figure.figsize':(15,8)})
sn.heatmap(corr_mat, annot=True)
plt.show()
